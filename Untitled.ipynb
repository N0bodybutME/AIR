# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
df = pd.read_csv('data.csv',encoding='unicode_escape')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8580\1402922042.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv',encoding='unicode_escape')

# %%
df
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
df.shape
# Out:
# (435742, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
df.isnull()
# Out:
#         stn_code  sampling_date  state  location  agency   type    so2    no2  \
# 0          False          False  False     False    True  False  False  False
# 1          False          False  False     False    True  False  False  False
# 2          False          False  False     False    True  False  False  False
# 3          False          False  False     False    True  False  False  False
# 4          False          False  False     False    True  False  False  False
# ...          ...            ...    ...       ...     ...    ...    ...    ...
# 435737     False          False  False     False   False  False  False  False
# 435738     False          False  False     False   False  False  False  False
# 435739      True           True  False      True    True   True   True   True
# 435740      True           True  False      True    True   True   True   True
# 435741      True           True  False      True    True   True   True   True
#
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# pm2_5                          426428
# spm                            237387
# agency                         149481
# stn_code                       144077
# rspm                            40222
# so2                             34646
# location_monitoring_station     27491
# no2                             16233
# type                             5393
# date                                7
# sampling_date                       3
# location                            3
# state                               0
# dtype: int64

# %%
df.describe()
# Out:
#                  so2            no2           rspm            spm        pm2_5
# count  401096.000000  419509.000000  395520.000000  198355.000000  9314.000000
# mean       10.829414      25.809623     108.832784     220.783480    40.791467
# std        11.177187      18.503086      74.872430     151.395457    30.832525
# min         0.000000       0.000000       0.000000       0.000000     3.000000
# 25%         5.000000      14.000000      56.000000     111.000000    24.000000
# 50%         8.000000      22.000000      90.000000     187.000000    32.000000
# 75%        13.700000      32.200000     142.000000     296.000000    46.000000
# max       909.000000     876.000000    6307.033333    3380.000000   504.000000

# %%
df.nunique()
# Out:
# stn_code                        803
# sampling_date                  5485
# state                            37
# location                        304
# agency                           64
# type                             10
# so2                            4197
# no2                            6864
# rspm                           6065
# spm                            6668
# location_monitoring_station     991
# pm2_5                           433
# date                           5067
# dtype: int64

# %%
sns.pairplot(data=df)

# %%
df['state'].value_counts()
# Out:
# state
# Maharashtra                    60384
# Uttar Pradesh                  42816
# Andhra Pradesh                 26368
# Punjab                         25634
# Rajasthan                      25589
# Kerala                         24728
# Himachal Pradesh               22896
# West Bengal                    22463
# Gujarat                        21279
# Tamil Nadu                     20597
# Madhya Pradesh                 19920
# Assam                          19361
# Odisha                         19279
# Karnataka                      17119
# Delhi                           8551
# Chandigarh                      8520
# Chhattisgarh                    7831
# Goa                             6206
# Jharkhand                       5968
# Mizoram                         5338
# Telangana                       3978
# Meghalaya                       3853
# Puducherry                      3785
# Haryana                         3420
# Nagaland                        2463
# ...

# %%
plt.figure(figsize=(15, 6))
df["state"].value_counts().plot(kind="bar")
plt.xticks(rotation=90)
plt.xlabel("State")
plt.ylabel("Number of Records")
plt.title("Number of Air Quality Records per State")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.xticks(rotation=90)
df['agency'].value_counts().plot(kind="bar")
plt.xlabel('Agency')
plt.ylabel('Frequencies')
plt.title("Number of agencies")
plt.tight_layout()
plt.show()

# %%
order = df.groupby("state")["so2"].mean().sort_values(ascending=False).index

sns.barplot(
    x="state",
    y="so2",
    data=df,
    order=order
)

plt.xticks(rotation=90)
plt.title("Average SO₂ Levels Across Indian States")
plt.xlabel("State")
plt.ylabel("SO₂ Concentration")
# Out:
# Text(0, 0.5, 'SO₂ Concentration')

# %%
order = df.groupby("state")["no2"].mean().sort_values(ascending=False).index

sns.barplot(
    x="state",
    y="no2",
    data=df,
    order=order
)

plt.xticks(rotation=90)
plt.title("Average nO₂ Levels Across Indian States")
plt.xlabel("State")
plt.ylabel("NO₂ Concentration")
# Out:
# Text(0, 0.5, 'NO₂ Concentration')

# %%
order = df.groupby("state")["rspm"].mean().sort_values(ascending=False).index

sns.barplot(
    x="state",
    y="rspm",
    data=df,
    order=order
)

plt.xticks(rotation=90)
plt.title("Average rspm Levels Across Indian States")
plt.xlabel("State")
plt.ylabel("rspm Concentration")
# Out:
# Text(0, 0.5, 'rspm Concentration')

# %%
order = df.groupby("state")["spm"].mean().sort_values(ascending=False).index

sns.barplot(
    x="state",
    y="spm",
    data=df,
    order=order
)

plt.xticks(rotation=90)
plt.title("Average spm Levels Across Indian States")
plt.xlabel("State")
plt.ylabel("spm Concentration")
# Out:
# Text(0, 0.5, 'spm Concentration')

# %%
order = df.groupby("state")["pm2_5"].mean().sort_values(ascending=False).index

sns.barplot(
    x="state",
    y="pm2_5",
    data=df,
    order=order
)

plt.xticks(rotation=90)
plt.title("Average pm2_5 Levels Across Indian States")
plt.xlabel("State")
plt.ylabel("pm2_5 Concentration")
# Out:
# Text(0, 0.5, 'pm2_5 Concentration')

# %%
df = df.drop(columns=["agency"], errors="ignore")

missing_count = df.isnull().sum()
missing_percent = (missing_count / len(df)) * 100
missing_summary = pd.DataFrame({
    "Missing_Count": missing_count,
    "Missing_Percent": missing_percent
})

missing_summary = missing_summary.sort_values(
    by="Missing_Percent",
    ascending=False
)

missing_summary
# Out:
#                              Missing_Count  Missing_Percent
# pm2_5                               426428        97.862497
# spm                                 237387        54.478797
# stn_code                            144077        33.064749
# rspm                                 40222         9.230692
# so2                                  34646         7.951035
# location_monitoring_station          27491         6.309009
# no2                                  16233         3.725370
# type                                  5393         1.237659
# date                                     7         0.001606
# sampling_date                            3         0.000688
# location                                 3         0.000688
# state                                    0         0.000000

# %%
cols_to_drop = [
    "agency",
    "stn_code",
    "location_monitoring_station"
]
df.drop(columns=cols_to_drop, inplace=True, errors="ignore")

df["sampling_date"] = pd.to_datetime(df["sampling_date"], errors="coerce")
df["Year"] = df["sampling_date"].dt.year
df["Month"] = df["sampling_date"].dt.month
df.drop(columns=["sampling_date"], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8580\1936687287.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["sampling_date"] = pd.to_datetime(df["sampling_date"], errors="coerce")

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# pm2_5       426428
# spm         237387
# rspm         40222
# so2          34646
# Year         23047
# Month        23047
# no2          16233
# type          5393
# date             7
# location         3
# state            0
# dtype: int64

# %%
for col in ["location", "type"]:
    df[col] = df[col].fillna(df[col].mode()[0])

numeric_cols = df.select_dtypes(include="number").columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
df.isnull().sum()
# Out:
# state       0
# location    0
# type        0
# so2         0
# no2         0
# rspm        0
# spm         0
# pm2_5       0
# date        7
# Year        0
# Month       0
# dtype: int64

# %%
df
# Out:
#                               state   location  \
# 0                    Andhra Pradesh  Hyderabad
# 1                    Andhra Pradesh  Hyderabad
# 2                    Andhra Pradesh  Hyderabad
# 3                    Andhra Pradesh  Hyderabad
# 4                    Andhra Pradesh  Hyderabad
# ...                             ...        ...
# 435737                  West Bengal   ULUBERIA
# 435738                  West Bengal   ULUBERIA
# 435739  andaman-and-nicobar-islands   Guwahati
# 435740                  Lakshadweep   Guwahati
# 435741                      Tripura   Guwahati
#
#                                       type   so2   no2   rspm    spm  pm2_5  \
# 0       Residential, Rural and other Areas   4.8  17.4   90.0  187.0   32.0
# 1                          Industrial Area   3.1   7.0   90.0  187.0   32.0
# 2       Residential, Rural and other Areas   6.2  28.5   90.0  187.0   32.0
# 3       Residential, Rural and other Areas   6.3  14.7   90.0  187.0   32.0
# ...

# %%
def cal_SOi(so2):
    si=0
    if (so2<=40):
     si= so2*(50/40)
    elif (so2>40 and so2<=80):
     si= 50+(so2-40)*(50/40)
    elif (so2>80 and so2<=380):
     si= 100+(so2-80)*(100/300)
    elif (so2>380 and so2<=800):
     si= 200+(so2-380)*(100/420)
    elif (so2>800 and so2<=1600):
     si= 300+(so2-800)*(100/800)
    elif (so2>1600):
     si= 400+(so2-1600)*(100/800)
    return si
df['SOi']=df['so2'].apply(cal_SOi)
data= df[['so2','SOi']]
data.head()
# Out:
#    so2    SOi
# 0  4.8  6.000
# 1  3.1  3.875
# 2  6.2  7.750
# 3  6.3  7.875
# 4  4.7  5.875

# %%
def cal_Noi(no2):
    ni=0
    if(no2<=40):
     ni= no2*50/40
    elif(no2>40 and no2<=80):
     ni= 50+(no2-40)*(50/40)
    elif(no2>80 and no2<=180):
     ni= 100+(no2-80)*(100/100)
    elif(no2>180 and no2<=280):
     ni= 200+(no2-180)*(100/100)
    elif(no2>280 and no2<=400):
     ni= 300+(no2-280)*(100/120)
    else:
     ni= 400+(no2-400)*(100/120)
    return ni
df['Noi']=df['no2'].apply(cal_Noi)
data= df[['no2','Noi']]
data.head()
# Out:
#     no2     Noi
# 0  17.4  21.750
# 1   7.0   8.750
# 2  28.5  35.625
# 3  14.7  18.375
# 4   7.5   9.375

# %%
def cal_RSPMI(rspm):
    rpi=0
    if(rpi<=30):
     rpi=rpi*50/30
    elif(rpi>30 and rpi<=60):
     rpi=50+(rpi-30)*50/30
    elif(rpi>60 and rpi<=90):
     rpi=100+(rpi-60)*100/30
    elif(rpi>90 and rpi<=120):
     rpi=200+(rpi-90)*100/30
    elif(rpi>120 and rpi<=250):
     rpi=300+(rpi-120)*(100/130)
    else:
     rpi=400+(rpi-250)*(100/130)
    return rpi
df['Rpi']=df['rspm'].apply(cal_RSPMI)
data= df[['rspm','Rpi']]
data.head()
# Out:
#    rspm  Rpi
# 0  90.0  0.0
# 1  90.0  0.0
# 2  90.0  0.0
# 3  90.0  0.0
# 4  90.0  0.0

# %%
def cal_SPMi(spm):
    spi=0
    if(spm<=50):
     spi=spm*50/50
    elif(spm>50 and spm<=100):
     spi=50+(spm-50)*(50/50)
    elif(spm>100 and spm<=250):
     spi= 100+(spm-100)*(100/150)
    elif(spm>250 and spm<=350):
     spi=200+(spm-250)*(100/100)
    elif(spm>350 and spm<=430):
     spi=300+(spm-350)*(100/80)
    else:
     spi=400+(spm-430)*(100/430)
    return spi
   
df['SPMi']=df['spm'].apply(cal_SPMi)
data= df[['spm','SPMi']]
data.head()
# Out:
#      spm   SPMi
# 0  187.0  158.0
# 1  187.0  158.0
# 2  187.0  158.0
# 3  187.0  158.0
# 4  187.0  158.0

# %%
def cal_SPMi(spm):
    spi=0
    if(spm<=50):
     spi=spm*50/50
    elif(spm>50 and spm<=100):
     spi=50+(spm-50)*(50/50)
    elif(spm>100 and spm<=250):
     spi= 100+(spm-100)*(100/150)
    elif(spm>250 and spm<=350):
     spi=200+(spm-250)*(100/100)
    elif(spm>350 and spm<=430):
     spi=300+(spm-350)*(100/80)
    else:
     spi=400+(spm-430)*(100/430)
    return spi
   
df['SPMi']=df['spm'].apply(cal_SPMi)
data= df[['spm','SPMi']]
data.head()
# Out:
#      spm   SPMi
# 0  187.0  158.0
# 1  187.0  158.0
# 2  187.0  158.0
# 3  187.0  158.0
# 4  187.0  158.0

# %%
def cal_aqi(si,ni,rspmi,spmi):
    aqi=0
    if(si>ni and si>rspmi and si>spmi):
     aqi=si
    if(ni>si and ni>rspmi and ni>spmi):
     aqi=ni
    if(rspmi>si and rspmi>ni and rspmi>spmi):
     aqi=rspmi
    if(spmi>si and spmi>ni and spmi>rspmi):
     aqi=spmi
    return aqi

df['AQI']=df.apply(lambda x:cal_aqi(x['SOi'],x['Noi'],x['Rpi'],x['SPMi']),axis=1)
data= df[['state','SOi','Noi','Rpi','SPMi','AQI']]
data.head()
# Out:
#             state    SOi     Noi  Rpi   SPMi    AQI
# 0  Andhra Pradesh  6.000  21.750  0.0  158.0  158.0
# 1  Andhra Pradesh  3.875   8.750  0.0  158.0  158.0
# 2  Andhra Pradesh  7.750  35.625  0.0  158.0  158.0
# 3  Andhra Pradesh  7.875  18.375  0.0  158.0  158.0
# 4  Andhra Pradesh  5.875   9.375  0.0  158.0  158.0

# %%
def AQI_Range(aqi):
    if aqi <= 50:
        return "Good"
    elif aqi <= 100:
        return "Moderate"
    elif aqi <= 200:
        return "Poor"
    elif aqi <= 300:
        return "Very Poor"
    elif aqi <= 400:
        return "Severe"
    else:
        return "Hazardous"

df['AQI_Range'] = df['AQI'] .apply(AQI_Range)
df.head()
# Out:
#             state   location                                type  so2   no2  \
# 0  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  4.8  17.4
# 1  Andhra Pradesh  Hyderabad                     Industrial Area  3.1   7.0
# 2  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.2  28.5
# 3  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.3  14.7
# 4  Andhra Pradesh  Hyderabad                     Industrial Area  4.7   7.5
#
#    rspm    spm  pm2_5        date    Year  Month    SOi     Noi  Rpi   SPMi  \
# 0  90.0  187.0   32.0  1990-02-01  2011.0    7.0  6.000  21.750  0.0  158.0
# 1  90.0  187.0   32.0  1990-02-01  2011.0    7.0  3.875   8.750  0.0  158.0
# 2  90.0  187.0   32.0  1990-02-01  2011.0    7.0  7.750  35.625  0.0  158.0
# 3  90.0  187.0   32.0  1990-03-01  2011.0    7.0  7.875  18.375  0.0  158.0
# 4  90.0  187.0   32.0  1990-03-01  2011.0    7.0  5.875   9.375  0.0  158.0
#
#      AQI AQI_Range
# 0  158.0      Poor
# ...

# %%
df['AQI_Range'].value_counts()
# Out:
# AQI_Range
# Poor         327002
# Very Poor     31733
# Moderate      30473
# Hazardous     18700
# Severe        15823
# Good          12011
# Name: count, dtype: int64

# %%
X=df[['SOi','Noi','Rpi','SPMi']]
Y=df['AQI']
X.head()
# Out:
#      SOi     Noi  Rpi   SPMi
# 0  6.000  21.750  0.0  158.0
# 1  3.875   8.750  0.0  158.0
# 2  7.750  35.625  0.0  158.0
# 3  7.875  18.375  0.0  158.0
# 4  5.875   9.375  0.0  158.0

# %%
Y.head()
# Out:
# 0    158.0
# 1    158.0
# 2    158.0
# 3    158.0
# 4    158.0
# Name: AQI, dtype: float64

# %%
df["date"] = pd.to_datetime(df["date"], errors="coerce")

# %%
df = df.sort_values("date")

# %%
latest_df = df.groupby("location", as_index=False).last()

# %%
print("Original rows:", len(df))
print("Unique locations:", df["location"].nunique())
print("Rows after filtering:", len(latest_df))
# Out:
# Original rows: 435742
# Unique locations: 304
# Rows after filtering: 304

# %%
latest_df.to_csv("air_quality_latest_by_city.csv", index=False)

# %%
df
# Out:
#                               state    location  \
# 413276                  West Bengal      Haldia
# 413279                  West Bengal      Howrah
# 413282                  West Bengal      Howrah
# 368217                Uttar Pradesh        Agra
# 80622                       Gujarat      Baroda
# ...                             ...         ...
# 245355                  Maharashtra  Chandrapur
# 284318                       Odisha    Balasore
# 435739  andaman-and-nicobar-islands    Guwahati
# 435740                  Lakshadweep    Guwahati
# 435741                      Tripura    Guwahati
#
#                                       type    so2    no2   rspm    spm  pm2_5  \
# 413276                         Residential    8.0   38.2   90.0  201.0   32.0
# 413279                          Industrial  103.4  148.0   90.0  968.0   32.0
# 413282                          Industrial   26.9   72.9   90.0  778.0   32.0
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=70)
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (348593, 4) (87149, 4) (348593,) (87149,)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
train_pred=model.predict(X_train)
test_pred=model.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train,train_pred)))
RMSE_test=(np.sqrt(metrics.mean_squared_error(Y_test,test_pred)))
print("RMSE TrainingData = ",str(RMSE_train))
print("RMSE TestData = ",str(RMSE_test))
print('-'*50)
print('RSquared value on train:',model.score(X_train, Y_train))
print('RSquared value on test:',model.score(X_test, Y_test))
# Out:
# RMSE TrainingData =  3.9304211542623
# RMSE TestData =  3.302320208694697
# --------------------------------------------------
# RSquared value on train: 0.9974535577674661
# RSquared value on test: 0.9981985702814452

# %%
DT=DecisionTreeRegressor()
DT.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
train_preds=DT.predict(X_train)
test_preds=DT.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train,train_preds)))
RMSE_test=(np.sqrt(metrics.mean_squared_error(Y_test,test_preds)))
print("RMSE TrainingData = ",str(RMSE_train))
print("RMSE TestData = ",str(RMSE_test))
print('-'*50)
print('RSquared value on train:',DT.score(X_train, Y_train))
print('RSquared value on test:',DT.score(X_test, Y_test))
# Out:
# RMSE TrainingData =  2.325482374300752e-13
# RMSE TestData =  0.9084181680575674
# --------------------------------------------------
# RSquared value on train: 1.0
# RSquared value on test: 0.9998636828237154

# %%
plt.figure(figsize=(6,6))
plt.scatter(Y_test, test_pred, alpha=0.5)
plt.xlabel("Actual AQI")
plt.ylabel("Predicted AQI")
plt.title("Actual vs Predicted AQI (Linear Regression)")
plt.plot([Y_test.min(), Y_test.max()],
         [Y_test.min(), Y_test.max()],
         'r--')
plt.show()

# %%
residuals = Y_test - test_pred

plt.figure(figsize=(6,4))
plt.hist(residuals, bins=30)
plt.xlabel("Residual Error")
plt.ylabel("Frequency")
plt.title("Residual Error Distribution")
plt.show()
